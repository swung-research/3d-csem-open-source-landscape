# %% [markdown]
# # MarlimR3D - Meshes and Fields SimPEG

# %%
import discretize
import emg3d
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm

# %%
# %matplotlib inline

# %% [markdown]
# ## Load survey info

# %%
data = xr.load_dataset('marlim_survey.nc', engine='h5netcdf')

# %% [markdown]
# ## Load results from modellers
#
# ### Tensor Mesh: emg3d

# %%
egd = emg3d.load('results/emg3d_meshesfields.h5')
mesh_emg3d = egd['mesh']
efield_emg3d_fx = egd['fx']
efield_emg3d_fy = egd['fy']
# Out:
# Data loaded from «/Users/lindseyjh/git/simpeg-research/3d-csem-open-source-landscape/model-marlim/results/emg3d_meshesfields.h5»
# [emg3d v0.12.0 (format 0.12.0) on 2020-09-15T16:18:17.926653].

# %% [markdown]
# ### OcTree Mesh: SimPEG

# %%
# Lindsey from SimPEG
simpeg_mesh = discretize.TreeMesh.readUBC("SimPEG/simpeg_marlim_mesh.txt")

# %%
simpeg_mesh
# Out:
# OcTreeMesh: 0.00% filled
#
# Level : Number of cells               Mesh Extent               Cell Widths
# -----------------------           min     ,     max            min   ,   max
#   1   :        2             ---------------------------   --------------------
#   2   :       24          x:   287675.0   ,  492475.0        100.0   ,  102400.0
#   3   :       160         y:   7466999.0  ,  7569399.0       100.0   ,  102400.0
#   4   :       212         z:   -122880.0  ,   40960.0         40.0   ,  40960.0
#   5   :       263
#   6   :       504
#   7   :      1006
#   8   :      2579
#   9   :      11032
#  10   :      58416
#  11   :     201344
# -----------------------
# Total :     275542

# %%
simpeg_e = np.load("SimPEG/simpeg_marlim_fields.npy")
simpeg_e = simpeg_e.reshape(simpeg_mesh.nE, len(data.freqs), order="F")

# %%
fig, ax = plt.subplots(1, 3, figsize=(12, 3))
ax4 = ax[0]
ax5 = ax[1]
ax6 = ax[2]

lc = '0.4'
lw = 0.5

ax4.annotate('OcTree Mesh', (0.3, 0.5), xycoords='axes fraction')
simpeg_mesh.plotSlice(
    np.zeros(simpeg_mesh.nC), grid=True, normal="Y", ax=ax4,
    grid_opts={"lw":lw, "color":lc},
    pcolor_opts={"cmap":"bwr", "vmin":-1, "vmax":1}
)

# ax5 : Ex-field
ax5.annotate('SimPEG Ex-field', (0.3, 0.5), xycoords='axes fraction')
simpeg_mesh.plotSlice(
    np.abs(simpeg_mesh.aveEx2CC * simpeg_e[:simpeg_mesh.nEx, -1]), 
    normal="Y",
    ind=508,
    ax=ax5,
    pcolor_opts={"rasterized":True, "norm":LogNorm()}
)

# ax6 : Ey-field
ax6.annotate('SimPEG Ey-field', (0.3, 0.5), xycoords='axes fraction')
simpeg_mesh.plotSlice(
    np.abs(simpeg_mesh.aveEx2CC * simpeg_e[:simpeg_mesh.nEx, -1]), 
    normal="Y",
    ind=508,
    ax=ax6,
    pcolor_opts={"rasterized":True, "norm":LogNorm()}
)
# Out:
# (<matplotlib.cm.ScalarMappable at 0x13db24430>,)

# %% [markdown]
# ### Tetrahedral Mesh: custEM

# %%
# Raphael from custEM, as example (custEM/PETGEM use the same mesh)

# %% [markdown]
# ## Figures
#
# We create two figures:
# - Once the entire mesh; the x-/z-extent will be different for all mesh types, but we should set the xlim/zlim to the max-extent for all meshes on each individual as well, for easy comparison
# - Once for the survey zone.

# %%
# Define some appearances here, so we can easily change them for all
lc = '0.4'
lw = 0.5

for case in ['entire', 'survey']:

    # Min/max for pcolormesh, depending on case.
    if case == 'entire':
        vmin = 1e-25
        vmax = 1e-9
    else:
        vmin = 1e-18
        vmax = 1e-9

    # Initiate figure (axes shared)
    fig, axs = plt.subplots(3, 3, figsize=(11, 8)) #, sharey=True, sharex=True) Simpeg is in m
    ((ax1, ax2, ax3), (ax4, ax5, ax6), (ax7, ax8, ax9)) = axs


    # # # (A) TensorMesh (ax1-ax3) # # #
    
    # Get dimension from mesh
    xmin, xmax = mesh_emg3d.vectorNx[0]/1e3, mesh_emg3d.vectorNx[-1]/1e3
    zmin, zmax = mesh_emg3d.vectorNz[0]/1e3, mesh_emg3d.vectorNz[-1]/1e3
    
    # Plot horizontal and vertical lines
    ax1.vlines(mesh_emg3d.vectorNx/1e3, zmin, zmax, colors=lc, lw=lw)
    ax1.hlines(mesh_emg3d.vectorNz/1e3, xmin, xmax, colors=lc, lw=lw)

    # Plot Ex-field
    for ax, field in zip([ax2, ax3], [efield_emg3d_fx, efield_emg3d_fy]):
        cb = ax.pcolormesh(mesh_emg3d.vectorNx/1e3, mesh_emg3d.vectorNz/1e3,
                           abs(field.T), rasterized=True, 
                           norm=LogNorm(vmin=vmin, vmax=vmax))





    # # # (B) OcTreeMesh (ax4-ax6) # # #

    # Lindsey TODO:
    # Plot here the OcTree-mesh results for the x-z at y=7517812.0 (rec-location)
    #
    # ax4 : Mesh
    ax4.annotate('OcTree Mesh', (0.3, 0.5), xycoords='axes fraction')
    simpeg_mesh.plotSlice(
        np.zeros(simpeg_mesh.nC), grid=True, normal="Y", ax=ax4,
        grid_opts={"lw":lw, "color":lc},
        pcolor_opts={"cmap":"bwr", "vmin":-1, "vmax":1}
    )
    
    # ax5 : Ex-field
    ax5.annotate('SimPEG Ex-field', (0.3, 0.5), xycoords='axes fraction')
    simpeg_mesh.plotSlice(
        np.abs(simpeg_mesh.aveEx2CC * simpeg_e[:simpeg_mesh.nEx, -1]), 
        normal="Y",
        ind=508,
        ax=ax5,
        pcolor_opts={"rasterized":True, "norm":LogNorm(vmin=vmin, vmax=vmax)}
    )
    
    # ax6 : Ey-field
    ax6.annotate('SimPEG Ey-field', (0.3, 0.5), xycoords='axes fraction')
    simpeg_mesh.plotSlice(
        np.abs(simpeg_mesh.aveEx2CC * simpeg_e[:simpeg_mesh.nEx, -1]), 
        normal="Y",
        ind=508,
        ax=ax6,
        pcolor_opts={"rasterized":True, "norm":LogNorm(vmin=vmin, vmax=vmax)}
    )



    # # # (C) TetrahedralMesh (ax7-ax9) # # #

    # Raphael TODO:
    # Plot here the Tetrahedral-mesh results for the x-z at y=7517812.0 (rec-location)
    #
    # ax7 : Mesh
    ax7.annotate('Tetrahedra Mesh', (0.3, 0.5), xycoords='axes fraction')
    # ax8 : Ex-field
    ax8.annotate('custEM Ex-field', (0.3, 0.5), xycoords='axes fraction')
    # ax9 : Ey-field
    ax9.annotate('custEM Ey-field', (0.3, 0.5), xycoords='axes fraction')



#     # # # FINALIZE # # #
    
#     # Plot survey over meshes.
    for ax in axs[:, 0]:
        ilx = data.src_x[::2]
        ilz = data.data_il.attrs['src_z']
        recx = data.attrs['rec_x']
        recz = data.attrs['rec_z']
        if ax not in [ax4, ax5, ax6]:  # SimPEG is in m
            ilx = ilx/1e3
            ilz = ilz/1e3
            recx = recx/1e3
            recz = recz/1e3
            
        ax.plot(ilx, ilz,
                '.', label=f"Inline; {data.data_il.attrs['lineid']}")
        ax.plot(recx, recz, '*', label='Receiver')
    
    # Set x- and y-limits
    if case == 'survey':
        ax1.set_xlim([data.src_x[0]/1e3, data.src_x[-1]/1e3])
        ax1.set_ylim([-4, 0])
        
        ax4.set_xlim([data.src_x[0], data.src_x[-1]])
        ax4.set_ylim([-4e3, 0])
    else:  # => TODO: ADJUST to min/max of all meshes!!!
        ax1.set_xlim([xmin-1, xmax+1])
        ax1.set_ylim([zmin-1, zmax+1])
        
        ax4.set_xlim(1e3*np.r_[xmin-1, xmax+1])
        ax4.set_ylim(1e3*np.r_[zmin-1, zmax+1])
        
    # Titles and labels.
    ax1.set_title('Mesh')
    ax2.set_title('$|E_x|$-field, $f=1\,$Hz')
    ax3.set_title('$|E_y|$-field, $f=1\,$Hz')
    ax8.set_xlabel('Easting (km)')
    ax4.set_ylabel('Depth (km)')

    # Turn spines off, but ticks on all sides.
    for ax in axs.ravel():
        [ax.spines[k].set_visible(False) for k in ax.spines.keys()]
        ax.xaxis.set_ticks_position('both')
        ax.yaxis.set_ticks_position('both')
    
    # Reduce number of ticks.
    if case == 'survey':
        ax1.set_yticks([-4, -3, -2, -1, 0])
    #ax1.set_xticks(ax1.xaxis.get_ticklocs()[1::2])

    # Make tight, leave space for colorbar.
    fig.tight_layout(w_pad=0.01, rect=[0, 0, 0.95, 1])

    # Colorbar.
    c = fig.colorbar(cb, ax=axs, fraction=0.025)
    c.ax.set_title('V/m')

    # Save and show.
    fig.savefig(f'../manuscript/figures/results-marlim_{case}.pdf', bbox_inches='tight')
    fig.show()
# Out:
# <ipython-input-12-fc8ea287fef7>:148: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# <ipython-input-12-fc8ea287fef7>:148: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
emg3d.Report()
# Out:
# --------------------------------------------------------------------------------
#   Date: Sun Sep 20 15:18:30 2020 MDT
#
#                 OS : Darwin
#             CPU(s) : 8
#            Machine : x86_64
#       Architecture : 64bit
#                RAM : 16.0 GB
#        Environment : Jupyter
#
#   Python 3.8.5 | packaged by conda-forge | (default, Jul 31 2020, 02:18:36)
#   [Clang 10.0.1 ]
#
#              numpy : 1.19.1
#              scipy : 1.5.2
#              numba : 0.51.2
#              emg3d : 0.12.0
#            empymod : 2.0.2
#             xarray : 0.16.0
#         discretize : 0.5.1
#               h5py : 2.10.0
#         matplotlib : 3.3.0
#               tqdm : 4.48.2
#            IPython : 7.18.1
#
#   Intel(R) Math Kernel Library Version 2019.0.5 Product Build 20190808 for
#   Intel(R) 64 architecture applications
# --------------------------------------------------------------------------------
